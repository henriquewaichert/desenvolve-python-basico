# %% [markdown]
# # Módulo 2
#
# ## 2.3 Instruções e Expressões
#
# ### Q1
#
# Faça um programa que armazene o valor de 20 reais de salário por hora de um trabalhador, e o número de 40 horas trabalhadas na semana. Com essas informações, calcule e imprima:
# - Salário semanal bruto
# - Valor descontado por semana INSS (10% do bruto)
# - Valor descontado por semana pelo sindicato (5% do bruto)
# - Salário semanal líquido (Bruto - Descontos)

# %%
## Escreva e execute seu código aqui
valor_por_hora = 20
horas_trabalhadas = 40
percentual_INSS = 0.1
percentual_sindicato = 0.05

salario_bruto_semanal = valor_por_hora * horas_trabalhadas
desconto_INSS = salario_bruto_semanal * percentual_INSS
desconto_sindicato = salario_bruto_semanal * percentual_sindicato
salario_liquido_semanal = salario_bruto_semanal - desconto_INSS - desconto_sindicato

print("Salário semanal bruto:", salario_bruto_semanal, "reais")
print("Valor descontado por semana INSS (10% do bruto):", desconto_INSS, "reais")
print("Valor descontado por semana pelo sindicato (5% do bruto):", desconto_sindicato, "reais")
print("Salário semanal líquido (Bruto - Descontos):", salario_liquido_semanal, "reais")
# Out:
# Salário semanal bruto: 800 reais
# Valor descontado por semana INSS (10% do bruto): 80.0 reais
# Valor descontado por semana pelo sindicato (5% do bruto): 40.0 reais
# Salário semanal líquido (Bruto - Descontos): 680.0 reais

# %% [markdown]
# ### Q2
#
# Altere o programa anterior para a partir dos valores de horas trabalhadas por semana e salário por hora, calcular **em somente duas instruções**:
# - Salário semanal bruto
# - Salário semanal líquido com todos os descontos. Para a segunda instrução, realize todos os cálculos aritméticos em uma expressão composta.

# %%
## Escreva e execute seu código aqui
valor_por_hora = 20
horas_trabalhadas = 40
percentual_INSS = 0.1
percentual_sindicato = 0.05

salario_semanal_bruto, salario_semanal_liquido = valor_por_hora * horas_trabalhadas, valor_por_hora * horas_trabalhadas * (1 - percentual_INSS - percentual_sindicato)

print("Salário semanal bruto:", salario_semanal_bruto, "reais")
print("Salário semanal líquido com todos os descontos:", salario_semanal_liquido, "reais")
# Out:
# Salário semanal bruto: 800 reais
# Salário semanal líquido com todos os descontos: 680.0 reais

# %% [markdown]
# ### Q3
#
# Você está desenvolvendo um software de conversão de moeda e precisa calcular o valor equivalente em yuan chinês a partir de uma quantia em real. A taxa de câmbio é de 0.69 BRL (real) para 1 CNY (yuan). Escreva um programa que define em uma variável uma quantia em reais (BRL) e calcula o valor equivalente em yuan (CNY). Imprima o resultado.

# %%
## Escreva e execute seu código aqui
quantia_em_reais = 100  # Defina a quantia em reais
taxa_de_cambio = 0.69  # Taxa de câmbio de BRL para CNY

quantia_em_yuan = quantia_em_reais * taxa_de_cambio

print("O valor equivalente em yuan chinês é:", quantia_em_yuan, "CNY")
# Out:
# O valor equivalente em yuan chinês é: 69.0 CNY

# %% [markdown]
# ### Q4
#
# Você é um treinador de corrida e deseja calcular a velocidade média que um atleta precisa manter para completar a Maratona Internacional de São Silvestre, que tem uma distância total de 42.195 km. A fórmula para calcular a velocidade média ($v\_media$) é dada por $v\_media = \frac{distancia}{tempo}$ . Escreva um programa em Python para calcular a velocidade média necessária para completar a maratona em 3 horas.
#
# **Calcule e imprima o resultado em metros/segundo**, ou seja, converta a distância de quilômetros para metros ($metro = \frac{km}{1000}$) e a velocidade de horas para segundos $(segundo = \frac{hora}{3600})$.

# %%
## Escreva e execute seu código aqui
distancia_km = 42.195
tempo_horas = 3

distancia_metros = distancia_km * 1000
tempo_segundos = tempo_horas * 3600

velocidade_media = distancia_metros / tempo_segundos

print("A velocidade média necessária para completar a maratona em 3 horas é:", velocidade_media, "metros/segundo")
# Out:
# A velocidade média necessária para completar a maratona em 3 horas é: 3.9069444444444446 metros/segundo
